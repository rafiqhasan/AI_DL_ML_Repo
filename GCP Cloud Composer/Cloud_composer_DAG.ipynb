# %%
# Commented out IPython magic to ensure Python compatibility.
# %%bash
pip install apache-airflow
# Out:
# ...
#   Created wheel for unicodecsv: filename=unicodecsv-0.14.1-cp36-none-any.whl size=10767 sha256=38255bb5e47f94e1294fd02e8e58fc0aa3bdf2bd3e4a50d6f5b9f7cdb2722b53
#   Stored in directory: /root/.cache/pip/wheels/a6/09/e9/e800279c98a0a8c94543f3de6c8a562f60e51363ed26e71283
# ...
#   Created wheel for flask-appbuilder: filename=Flask_AppBuilder-1.13.1-cp36-none-any.whl size=1669856 sha256=e4e260a6e0ea089c885dc4d6a2f9d42ed9ae9a9bc3d247f7e309c62f10430452
#   Stored in directory: /root/.cache/pip/wheels/a3/cd/51/fca4f493641fca13f680317a1cf5be6c2c2f229d2eb5307658
# ...
#   Created wheel for alembic: filename=alembic-1.3.0-py2.py3-none-any.whl size=144427 sha256=f3f235858ce48af1fcef9bc047f35c6c6dbbb7e4800528d79d649716730700d4
#   Stored in directory: /root/.cache/pip/wheels/40/f8/22/ad0f408796a4c656fae5ee1fd8d8a139b19ca4af61059cea5b
# ...
#   Created wheel for flask-admin: filename=Flask_Admin-1.5.3-cp36-none-any.whl size=1853777 sha256=5628f8da76c9d23746d3ee0c93d454d1a3985706878af1cae49468ca1c06ce84
# ...

# %%
# %%bash
# airflow initdb

# %%
# # start the web server, default port is 8080
# %%bash
# airflow webserver -p 8080

# %%
##Rafiqh -> Cloud Composer Dummy
import datetime
import requests 

import airflow
from airflow.operators import DummyOperator
# Out:
# /usr/local/lib/python3.6/dist-packages/airflow/utils/helpers.py:428: DeprecationWarning: Importing 'DummyOperator' directly from 'airflow.operators' has been deprecated. Please import from 'airflow.operators.[operator_module]' instead. Support for direct imports will be dropped entirely in Airflow 2.0.
#   DeprecationWarning)

# %%
def download_data():
  file_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/annealing/anneal.data"
    
  r = requests.get(file_url, stream = True) 
    
  with open("datafile","wb") as f_: 
      for chunk in r.iter_content(chunk_size=1024): 
    
          # writing one chunk at a time to file 
          if chunk: 
              f_.write(chunk) 

download_data()

# %%
default_args = {
    'owner': 'Composer - rafiqh',
    'depends_on_past': False,
    'email': [''],
    'email_on_failure': False,
    'email_on_retry': False,
    'retries': 1,
    'retry_delay': datetime.timedelta(minutes=5),
    'start_date': datetime.datetime.now(),
}

with airflow.DAG(
        'rafiqh_composer_dag',
        'catchup=False',
        default_args=default_args,
        schedule_interval=datetime.timedelta(days=1)) as dag:

    #Dummy operations
    op1 = DummyOperator(task_id='get_API_export')

    op2 = DummyOperator(task_id='export_to_json_shards')

    op3 = DummyOperator(task_id='ML_train')

    op1 >> op2 >> op3
