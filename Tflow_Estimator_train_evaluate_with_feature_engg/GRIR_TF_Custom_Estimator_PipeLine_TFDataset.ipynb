# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import seaborn as sns
import scipy
import os
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from tensorflow.python.training import training_util

print(tf.__version__)
tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
# Out:
# c:\users\hrafiq\appdata\local\programs\python\python35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.10.0

# %%
df = pd.read_csv("GRIR_GCP_Data.csv", sep=",")

# %%
df.head(10)
# Out:
#   WERKS  SCENARIO  KTOKK  VSTATU  VPATD  EKORG EKGRP  TOTGRQTY  TOTIRQTY  \
# 0  ML01         3      1       1     30      1     A         0        80
# 1  ML01         3      1       1     30      1     A         0       107
# 2  ML01         3      1       1     30      1     A         0       107
# 3  ML01         3      1       1     30      1     A         0        96
# 4  ML01         3      1       1     30      1     A         0       146
# 5  ML01         3      1       1     60      1     A         0       189
# 6  ML01         3      1       1     60      1     A         0       183
# 7  ML01         3      1       1     60      1     A         0       159
# 8  ML01         3      1       1     60      1     A         0       185
# 9  ML01         3      1       1     60      1     A         0        91
#
#    NODLGR  NODLIR  DIFGRIRD  DIFGRIRV  STATUS
# 0       0      90       -80    -38100       1
# 1       0     177      -107    -41600       0
# 2       0     152      -107    -27600       1
# 3       0      79       -96    -13800       1
# 4       0     192      -146    -73500       0
# 5       0     139      -189    -26600       1
# 6       0      48      -183    -69200       0
# 7       0     195      -159    -73600       0
# 8       0      79      -185    -59500       0
# 9       0     168       -91     -4700       1

# %%
df.describe()
# Out:
#        SCENARIO  KTOKK  VSTATU  VPATD  EKORG  TOTGRQTY  TOTIRQTY  NODLGR  \
# count    8279.0 8279.0  8279.0 8279.0 8279.0    8279.0    8279.0  8279.0
# mean        2.6    1.5     1.1   60.3    1.3      65.9      94.1   103.1
# std         1.1    0.5     0.3   24.4    0.5      63.0      62.4    82.0
# min         1.0    1.0     1.0   30.0    1.0       0.0       0.0     0.0
# 25%         2.0    1.0     1.0   30.0    1.0       0.0      54.0     0.0
# 50%         3.0    1.0     1.0   60.0    1.0      55.0      99.0   112.0
# 75%         4.0    2.0     1.0   90.0    2.0     121.0     146.0   172.0
# max         4.0    2.0     2.0   90.0    2.0     200.0     200.0   268.0
#
#        NODLIR  DIFGRIRD  DIFGRIRV  STATUS
# count  8279.0    8279.0    8279.0  8279.0
# mean     89.5     -28.2   -6716.3     0.4
# std      75.0      63.2   22797.4     0.5
# min       0.0    -200.0  -75000.0     0.0
# 25%      10.0     -56.0   -9600.0     0.0
# 50%      82.0      -2.0    -546.0     0.0
# 75%     154.0      11.0    5482.0     1.0
# max     242.0      74.0   59200.0     1.0

# %%
df.columns
# Out:
# Index(['WERKS', 'SCENARIO', 'KTOKK', 'VSTATU', 'VPATD', 'EKORG', 'EKGRP',
#        'TOTGRQTY', 'TOTIRQTY', 'NODLGR', 'NODLIR', 'DIFGRIRD', 'DIFGRIRV',
#        'STATUS'],
#       dtype='object')

# %%
#Facet1
g = sns.FacetGrid(df, col="SCENARIO")
g = g.map(plt.hist, "TOTGRQTY")
plt.show()

# %%
#Facet1
g = sns.FacetGrid(df, col="SCENARIO")
g = g.map(plt.hist, "TOTIRQTY")
plt.show()

# %%
#Filter out scenario = 3 ( It has TOTGRQTY == 0 )
df_s1 = df[df['SCENARIO'].eq(3) & df['TOTGRQTY'].eq(0)]
df_s1.head()
# Out:
#   WERKS  SCENARIO  KTOKK  VSTATU  VPATD  EKORG EKGRP  TOTGRQTY  TOTIRQTY  \
# 0  ML01         3      1       1     30      1     A         0        80
# 1  ML01         3      1       1     30      1     A         0       107
# 2  ML01         3      1       1     30      1     A         0       107
# 3  ML01         3      1       1     30      1     A         0        96
# 4  ML01         3      1       1     30      1     A         0       146
#
#    NODLGR  NODLIR  DIFGRIRD  DIFGRIRV  STATUS
# 0       0      90       -80    -38100       1
# 1       0     177      -107    -41600       0
# 2       0     152      -107    -27600       1
# 3       0      79       -96    -13800       1
# 4       0     192      -146    -73500       0

# %%
#Mark some columns as categorical so that TF treats them as categorical
for col_cat in ['SCENARIO','KTOKK','VSTATU','EKORG']:
    df[col_cat] = df[col_cat].astype('str') #Very important to keep this as STR -> Tensorflow treats only STR as categorical
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8279 entries, 0 to 8278
# Data columns (total 14 columns):
# WERKS       8279 non-null object
# SCENARIO    8279 non-null object
# KTOKK       8279 non-null object
# VSTATU      8279 non-null object
# VPATD       8279 non-null int64
# EKORG       8279 non-null object
# EKGRP       8279 non-null object
# TOTGRQTY    8279 non-null int64
# TOTIRQTY    8279 non-null int64
# NODLGR      8279 non-null int64
# NODLIR      8279 non-null int64
# DIFGRIRD    8279 non-null int64
# DIFGRIRV    8279 non-null int64
# STATUS      8279 non-null int64
# dtypes: int64(8), object(6)
# memory usage: 905.6+ KB

# %%
#Split dataset -> Split 10 times and choose the one with best P values( Significance test )
p_res = {}
t_res = []
for i in range(10):
    np.random.seed(seed=i) #makes result reproducible
    msk = np.random.rand(len(df)) < 0.8
    X_train = df[msk]
    X_test = df[~msk]

    #Run Significance Tests on both the distributions( Train and Test ) for all numerical attributes
    p_res = {}
    for c_ in X_train.columns:
        if not X_train[c_].dtype == 'object':
            try:
                _, a = scipy.stats.ks_2samp(X_train[c_].values,X_test[c_].values)
                #print('P-value for column {} is {}'.format(c_.upper(), a))
                p_res['Random'] = i
                p_res[c_] = a
            except:
                p_res['Random'] = i
                p_res[c_] = 'Error'
    t_res.append(p_res)

p_df = pd.DataFrame(t_res)
p_df
# Out:
#    DIFGRIRD  DIFGRIRV  NODLGR  NODLIR  Random  STATUS  TOTGRQTY  TOTIRQTY  \
# 0       0.2       0.1     0.3     0.3       0     0.2       0.3       0.6
# 1       0.1       0.1     0.1     0.3       1     1.0       0.0       0.8
# 2       1.0       0.9     0.8     1.0       2     1.0       0.9       0.4
# 3       0.5       0.2     0.1     0.1       3     1.0       0.4       0.9
# 4       1.0       0.6     0.5     0.5       4     1.0       1.0       0.9
# 5       0.7       0.4     0.2     0.4       5     0.8       0.7       0.2
# 6       0.5       0.3     0.4     1.0       6     1.0       0.9       0.7
# 7       0.8       0.3     0.7     0.6       7     0.7       0.9       0.8
# 8       0.8       0.6     1.0     1.0       8     1.0       0.0       0.3
# 9       1.0       0.5     0.4     0.4       9     1.0       0.0       0.1
#
#    VPATD
# 0    0.9
# 1    1.0
# 2    0.8
# 3    1.0
# 4    1.0
# 5    1.0
# 6    0.3
# 7    0.6
# 8    0.4
# 9    1.0

# %%
#Prepare train and test data set
np.random.seed(seed=2) #makes result reproducible
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]
#evaldf[evaldf['STATUS'] == 1]

# %%
traindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6629 entries, 0 to 8278
# Data columns (total 14 columns):
# WERKS       6629 non-null object
# SCENARIO    6629 non-null object
# KTOKK       6629 non-null object
# VSTATU      6629 non-null object
# VPATD       6629 non-null int64
# EKORG       6629 non-null object
# EKGRP       6629 non-null object
# TOTGRQTY    6629 non-null int64
# TOTIRQTY    6629 non-null int64
# NODLGR      6629 non-null int64
# NODLIR      6629 non-null int64
# DIFGRIRD    6629 non-null int64
# DIFGRIRV    6629 non-null int64
# STATUS      6629 non-null int64
# dtypes: int64(8), object(6)
# memory usage: 776.8+ KB

# %%
evaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1650 entries, 16 to 8272
# Data columns (total 14 columns):
# WERKS       1650 non-null object
# SCENARIO    1650 non-null object
# KTOKK       1650 non-null object
# VSTATU      1650 non-null object
# VPATD       1650 non-null int64
# EKORG       1650 non-null object
# EKGRP       1650 non-null object
# TOTGRQTY    1650 non-null int64
# TOTIRQTY    1650 non-null int64
# NODLGR      1650 non-null int64
# NODLIR      1650 non-null int64
# DIFGRIRD    1650 non-null int64
# DIFGRIRV    1650 non-null int64
# STATUS      1650 non-null int64
# dtypes: int64(8), object(6)
# memory usage: 193.4+ KB

# %%
#Files To be used in Tensorflow pipeline dataset API
traindf.to_csv("grir_train.csv", index=False, header=False)
evaldf.to_csv("grir_eval.csv", index=False, header=False)

# %%
######################################## Tensorflow Pipeline building and Modeling ############################################

# %%
#Tf version of Add_new_features
def add_new_features_tf(df_temp):   
    #Add any feature engineering or new column here
    df_temp['grminusirbyvpatd'] = ( df_temp['TOTGRQTY'] - df_temp['TOTIRQTY'] ) / df_temp['VPATD']
    
    df_temp['difgrirdbytotgrqty'] = tf.where( tf.not_equal(tf.cast(df_temp['TOTGRQTY'], tf.float32), tf.cast(0, tf.float32)),
                                              tf.cast(tf.divide(df_temp['DIFGRIRD'], df_temp['TOTGRQTY']), tf.float32),
                                              tf.cast(tf.zeros_like(df_temp['DIFGRIRD']), tf.float32))
    return df_temp

# %%
#Panda version of Add_new_features
def add_new_features_panda(df_temp):   
    def feat_difgrirdbytotgrqty(row):
        if row['TOTGRQTY'] == 0:
            return 0
        else:
            return row['DIFGRIRD'] / row['TOTGRQTY']
    
    #Add any feature engineering or new column here
    df_temp['grminusirbyvpatd'] = ( df_temp['TOTGRQTY'] - df_temp['TOTIRQTY'] ) / df_temp['VPATD']
    
    df_temp['difgrirdbytotgrqty'] = df_temp.apply(feat_difgrirdbytotgrqty, axis=1)
    return df_temp

# %%
# Test add_new_features for X_train
df_dummy = add_new_features_panda(traindf.copy())
print(df_dummy.head())
print(df_dummy.describe())
# Out:
#   WERKS SCENARIO KTOKK VSTATU  VPATD EKORG EKGRP  TOTGRQTY  TOTIRQTY  NODLGR  \
# 0  ML01        3     1      1     30     1     A         0        80       0
# 1  ML01        3     1      1     30     1     A         0       107       0
# 2  ML01        3     1      1     30     1     A         0       107       0
# 3  ML01        3     1      1     30     1     A         0        96       0
# 4  ML01        3     1      1     30     1     A         0       146       0
#
#    NODLIR  DIFGRIRD  DIFGRIRV  STATUS  grminusirbyvpatd  difgrirdbytotgrqty
# 0      90       -80    -38100       1              -2.7                 0.0
# 1     177      -107    -41600       0              -3.6                 0.0
# 2     152      -107    -27600       1              -3.6                 0.0
# 3      79       -96    -13800       1              -3.2                 0.0
# 4     192      -146    -73500       0              -4.9                 0.0
#        VPATD  TOTGRQTY  TOTIRQTY  NODLGR  NODLIR  DIFGRIRD  DIFGRIRV  STATUS  \
# count 6629.0    6629.0    6629.0  6629.0  6629.0    6629.0    6629.0  6629.0
# mean    60.4      65.9      94.2   103.1    89.5     -28.3   -6720.6     0.4
# std     24.4      63.0      62.5    81.9    75.0      63.3   22747.0     0.5
# min     30.0       0.0       0.0     0.0     0.0    -200.0  -75000.0     0.0
# 25%     30.0       0.0      54.0     0.0    10.0     -57.0   -9637.0     0.0
# 50%     60.0      55.0     100.0   112.0    82.0      -2.0    -566.0     0.0
# 75%     90.0     122.0     146.0   172.0   153.0      11.0    5500.0     1.0
# max     90.0     200.0     200.0   268.0   242.0      74.0   59200.0     1.0
#
#        grminusirbyvpatd  difgrirdbytotgrqty
# count            6629.0              6629.0
# mean               -0.6                 0.2
# std                 1.4                 0.4
# min                -6.7                -0.2
# 25%                -0.8                -0.0
# 50%                -0.0                 0.0
# 75%                 0.2                 0.1
# max                 1.7                 1.0

# %%
#RETURNS a pre-processing( New columns + Transformations ) function to be used inside pipeline
def create_add_engineered_fn(df):
    #Add new features in the set so that it's details can be copied to parameters of fn_add_engineered
    df = add_new_features_panda(df)
    
    #Get min max for each numerical column to use for scaling
    cols_mean = {}
    cols_std = {}
    num_feats = []
    for col_norm in list(df.columns):
        if not df[col_norm].dtype == 'object' and not col_norm in ['STATUS']:
            cols_mean[col_norm] = df[col_norm].mean()
            cols_std[col_norm] = df[col_norm].std()
            num_feats.append(col_norm)

    #Pass all the above calculated values to be used by main function which will be called in Pipeline
    def fn_add_engineered(features, cols_mean = cols_mean, cols_std = cols_std, num_feats = num_feats):
        #Save value here for 0-1 scaling during training and serving
#         print("mean", cols_mean)
#         print("std", cols_std)
#         print(features)
        
        #Add new features AGAIN as the function add_engineered will be called with data
        features = add_new_features_tf(features)
        
        #Normalize few numerical columns
        for col_norm in list(num_feats):
            mean_value = cols_mean[col_norm]
            std_value = cols_std[col_norm]
            features[col_norm] = (features[col_norm] - mean_value) / std_value

#         print("..... Done processing ")
#         print(features)
        return features
    
    return fn_add_engineered

#Generate pre-processing function as per training data
add_engineered = create_add_engineered_fn(traindf.copy())

# %%
#Test run add_engineered on copy of X_test
# dummy = traindf.copy()
# dummy = add_engineered(dummy)
# dummy.describe()

# %%
# Define your feature columns
def create_feature_cols():
#   lat_buck = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'), 
#                                                  boundaries = np.arange(32.0, 42, 1).tolist())
#   long_buck = tf.feature_column.bucketized_column(tf.feature_column.numeric_column('longitude'),
#                                                   boundaries = np.arange(1, 52, 1).tolist())
    werks_c = tf.feature_column.categorical_column_with_vocabulary_list(
            key='WERKS',
            vocabulary_list=['ML01','ML02','ML03'])
    scenario_c = tf.feature_column.categorical_column_with_vocabulary_list(
            key='SCENARIO',
            vocabulary_list=['1','2','3','4'])
    ktokk_c = tf.feature_column.categorical_column_with_vocabulary_list(
            key='KTOKK',
            vocabulary_list=['1','2'])    
    vstatu_c = tf.feature_column.categorical_column_with_vocabulary_list(
            key='VSTATU',
            vocabulary_list=['1','2'])
    ekorg_c = tf.feature_column.categorical_column_with_vocabulary_list(
            key='EKORG',
            vocabulary_list=['1','2'])   
    ekgrp_c = tf.feature_column.categorical_column_with_vocabulary_list(
            key='EKGRP',
            vocabulary_list=['A','B','C'])
    
#     werks_c = tf.feature_column.categorical_column_with_hash_bucket(
#             key='WERKS',hash_bucket_size=3)
#     scenario_c = tf.feature_column.categorical_column_with_hash_bucket(
#             key='SCENARIO',hash_bucket_size=4)
#     ktokk_c = tf.feature_column.categorical_column_with_hash_bucket(
#             key='KTOKK',hash_bucket_size=2)
#     vstatu_c = tf.feature_column.categorical_column_with_hash_bucket(
#             key='VSTATU',hash_bucket_size=2)
#     ekorg_c = tf.feature_column.categorical_column_with_hash_bucket(
#             key='EKORG',hash_bucket_size=2)
#     ekgrp_c = tf.feature_column.categorical_column_with_hash_bucket(
#             key='EKGRP',hash_bucket_size=3)

    return [
        tf.feature_column.indicator_column(werks_c),
        tf.feature_column.indicator_column(scenario_c),
        tf.feature_column.indicator_column(ktokk_c),
        tf.feature_column.indicator_column(vstatu_c),
        tf.feature_column.indicator_column(ekorg_c),
        tf.feature_column.indicator_column(ekgrp_c),
        tf.feature_column.numeric_column('VPATD'),
        tf.feature_column.numeric_column("TOTGRQTY"),
        tf.feature_column.numeric_column("TOTIRQTY"),
        tf.feature_column.numeric_column("NODLGR"),
        tf.feature_column.numeric_column("NODLIR"),
        tf.feature_column.numeric_column("DIFGRIRD"),
        tf.feature_column.numeric_column("grminusirbyvpatd"),
        tf.feature_column.numeric_column("difgrirdbytotgrqty"),
        tf.feature_column.numeric_column("DIFGRIRV")
  ]

# %%
traindf.columns
# Out:
# Index(['WERKS', 'SCENARIO', 'KTOKK', 'VSTATU', 'VPATD', 'EKORG', 'EKGRP',
#        'TOTGRQTY', 'TOTIRQTY', 'NODLGR', 'NODLIR', 'DIFGRIRD', 'DIFGRIRV',
#        'STATUS'],
#       dtype='object')

# %%
# Create input function to load data into datasets
CSV_COLUMNS = traindf.columns  #['WERKS', 'SCENARIO', 'KTOKK', 'VSTATU', 'VPATD', 'EKORG', 'EKGRP',
                               #'TOTGRQTY', 'TOTIRQTY', 'NODLGR', 'NODLIR', 'DIFGRIRD', 'DIFGRIRV',
                               #'STATUS']
LABEL_COLUMN = 'STATUS'
DEFAULTS = [['ML01'],['3'], ['1'], ['1'], [30.0], ['1'], ['A'], [0.], [80.0], [0.], [90.0], [-80.0], [-38100.0], [1]]  #First row is passed

def read_dataset(filename, mode, batch_size = 512):
    def _input_fn(v_test=False):
        def decode_csv(value_column):
            columns = tf.decode_csv(value_column, record_defaults = DEFAULTS)
            features = dict(zip(CSV_COLUMNS, columns))
            label = features.pop(LABEL_COLUMN)
            return add_engineered(features), label
        
        # Create list of files that match pattern
        file_list = tf.gfile.Glob(filename)

        # Create dataset from file list
        dataset = tf.data.TextLineDataset(file_list).map(decode_csv)

        if mode == tf.estimator.ModeKeys.TRAIN:
            num_epochs = None # indefinitely
            dataset = dataset.shuffle(buffer_size = 10 * batch_size)
        else:
            num_epochs = 1 # end-of-input after this

        dataset = dataset.repeat(num_epochs).batch(batch_size)
        batch_features, batch_labels = dataset.make_one_shot_iterator().get_next()
        
        #Begins - Uncomment for testing only -----------------------------------------------------<
        if v_test == True:
            with tf.Session() as sess:
                print(sess.run(batch_features))
        #End - Uncomment for testing only -----------------------------------------------------<
        return batch_features, batch_labels
    return _input_fn

# Serving function for external call
def serving_fn():
    feature_placeholders  = {'WERKS' : tf.placeholder(tf.string, [None]),
            'SCENARIO' : tf.placeholder(tf.string, [None]),
            'KTOKK' : tf.placeholder(tf.string, [None]),
            'VSTATU' : tf.placeholder(tf.string, [None]),
            'EKORG' : tf.placeholder(tf.string, [None]),
            'EKGRP' : tf.placeholder(tf.string, [None]),
            'VPATD' : tf.placeholder(tf.float32, [None]),
            'TOTGRQTY' : tf.placeholder(tf.float32, [None]),
            'TOTIRQTY' : tf.placeholder(tf.float32, [None]),
            'NODLGR' : tf.placeholder(tf.float32, [None]),
            'NODLIR' : tf.placeholder(tf.float32, [None]),
            'DIFGRIRD' : tf.placeholder(tf.float32, [None]),
            'DIFGRIRV' : tf.placeholder(tf.float32, [None])
    }

    #Features with transformation logic
    features = {
                key: tf.expand_dims(tensor, -1)
                for key, tensor in feature_placeholders.items()
            }
    
    #feat_changed = add_engineered(features.copy())
    return tf.estimator.export.ServingInputReceiver(add_engineered(features), feature_placeholders )
#serving_fn()

# %%
#Test dataset read function
eval_file = os.getcwd() + "\grir_train.csv"
fn_d = read_dataset(filename = eval_file,
                    mode = tf.estimator.ModeKeys.EVAL,
                    batch_size = 20)

fn_d(v_test=True)
# Out:
# {'TOTGRQTY': array([-1.045735, -1.045735, -1.045735, -1.045735, -1.045735, -1.045735,
#        -1.045735, -1.045735, -1.045735, -1.045735, -1.045735, -1.045735,
#        -1.045735, -1.045735, -1.045735, -1.045735, -1.045735, -1.045735,
#        -1.045735, -1.045735], dtype=float32), 'WERKS': array([b'ML01', b'ML01', b'ML01', b'ML01', b'ML01', b'ML01', b'ML01',
#        b'ML01', b'ML01', b'ML01', b'ML01', b'ML01', b'ML01', b'ML01',
#        b'ML01', b'ML01', b'ML01', b'ML01', b'ML01', b'ML01'], dtype=object), 'NODLGR': array([-1.2586846, -1.2586846, -1.2586846, -1.2586846, -1.2586846,
#        -1.2586846, -1.2586846, -1.2586846, -1.2586846, -1.2586846,
#        -1.2586846, -1.2586846, -1.2586846, -1.2586846, -1.2586846,
#        -1.2586846, -1.2586846, -1.2586846, -1.2586846, -1.2586846],
#       dtype=float32), 'DIFGRIRV': array([-1.3794957 , -1.5333624 , -0.917896  , -0.31122202, -2.9357464 ,
#        -0.8739341 , -2.7467105 , -2.9401426 , -2.32028   ,  0.08883115,
#        -1.757568  , -0.03865832, -2.0257356 , -1.2783835 , -1.0629703 ,
#        -0.98383886, -2.3114877 , -0.4255229 , -0.7948027 , -2.1268477 ],
#       dtype=float32), 'EKGRP': array([b'A', b'A', b'A', b'A', b'A', b'A', b'A', b'A', b'A', b'A', b'A',
#        b'A', b'A', b'A', b'A', b'A', b'A', b'A', b'A', b'A'], dtype=object), 'VSTATU': array([b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1',
#        b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1'], dtype=object), 'grminusirbyvpatd': array([-1.4461993 , -2.0698836 , -2.0698836 , -1.81579   , -2.970761  ,
#        -1.7811409 , -1.7118425 , -1.4346496 , -1.734942  , -0.64926934,
#        -0.32972744, -0.5684214 , -0.8148152 , -1.0150102 , -0.9226125 ,
#        -2.2777781 , -3.80234   , -2.7397666 , -1.6425444 , -1.1690062 ],
#       dtype=float32), 'DIFGRIRD': array([-0.8159822 , -1.2422822 , -1.2422822 , -1.0686044 , -1.8580487 ,
#        -2.5369709 , -2.4422376 , -2.0633044 , -2.4738154 , -0.98965997,
#        -1.0528156 , -1.542271  , -2.0475154 , -2.4580266 , -2.26856   ,
#        -1.3843821 , -2.4264488 , -1.7001599 , -2.3475044 , -1.7001599 ],
#       dtype=float32), 'NODLIR': array([ 0.00666673,  1.1668546 ,  0.8334673 , -0.1400237 ,  1.3668871 ,
#         0.6601059 , -0.553424  ,  1.4068935 , -0.1400237 ,  1.0468352 ,
#        -0.64677244, -0.51341754,  0.526751  , -1.1668566 ,  0.8334673 ,
#         0.7001124 , -0.10001722, -0.24670765, -1.0735083 , -0.8868113 ],
#       dtype=float32), 'difgrirdbytotgrqty': array([-0.51340175, -0.51340175, -0.51340175, -0.51340175, -0.51340175,
#        -0.51340175, -0.51340175, -0.51340175, -0.51340175, -0.51340175,
#        -0.51340175, -0.51340175, -0.51340175, -0.51340175, -0.51340175,
#        -0.51340175, -0.51340175, -0.51340175, -0.51340175, -0.51340175],
#       dtype=float32), 'EKORG': array([b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1',
#        b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1'], dtype=object), 'VPATD': array([-1.242383 , -1.242383 , -1.242383 , -1.242383 , -1.242383 ,
#        -0.0151804, -0.0151804, -0.0151804, -0.0151804, -0.0151804,
#         1.2120222,  1.2120222,  1.2120222,  1.2120222,  1.2120222,
#        -1.242383 , -1.242383 , -1.242383 , -0.0151804, -0.0151804],
#       dtype=float32), 'KTOKK': array([b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1',
#        b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1', b'1'], dtype=object), 'SCENARIO': array([b'3', b'3', b'3', b'3', b'3', b'3', b'3', b'3', b'3', b'3', b'3',
#        b'3', b'3', b'3', b'3', b'3', b'3', b'3', b'3', b'3'], dtype=object), 'TOTIRQTY': array([-0.22744055,  0.20457521,  0.20457521,  0.02856879,  0.82859796,
#         1.5166231 ,  1.4206196 ,  1.0366056 ,  1.4526207 , -0.05143413,
#         0.01256821,  0.5085863 ,  1.020605  ,  1.4366201 ,  1.2446132 ,
#         0.34858048,  1.404619  ,  0.66859215,  1.3246161 ,  0.66859215],
#       dtype=float32)}
# ({'DIFGRIRD': <tf.Tensor 'IteratorGetNext:0' shape=(?,) dtype=float32>,
#   'DIFGRIRV': <tf.Tensor 'IteratorGetNext:1' shape=(?,) dtype=float32>,
#   'EKGRP': <tf.Tensor 'IteratorGetNext:2' shape=(?,) dtype=string>,
#   'EKORG': <tf.Tensor 'IteratorGetNext:3' shape=(?,) dtype=string>,
#   'KTOKK': <tf.Tensor 'IteratorGetNext:4' shape=(?,) dtype=string>,
#   'NODLGR': <tf.Tensor 'IteratorGetNext:5' shape=(?,) dtype=float32>,
#   'NODLIR': <tf.Tensor 'IteratorGetNext:6' shape=(?,) dtype=float32>,
#   'SCENARIO': <tf.Tensor 'IteratorGetNext:7' shape=(?,) dtype=string>,
#   'TOTGRQTY': <tf.Tensor 'IteratorGetNext:8' shape=(?,) dtype=float32>,
#   'TOTIRQTY': <tf.Tensor 'IteratorGetNext:9' shape=(?,) dtype=float32>,
#   'VPATD': <tf.Tensor 'IteratorGetNext:10' shape=(?,) dtype=float32>,
#   'VSTATU': <tf.Tensor 'IteratorGetNext:11' shape=(?,) dtype=string>,
#   'WERKS': <tf.Tensor 'IteratorGetNext:12' shape=(?,) dtype=string>,
#   'difgrirdbytotgrqty': <tf.Tensor 'IteratorGetNext:13' shape=(?,) dtype=float32>,
#   'grminusirbyvpatd': <tf.Tensor 'IteratorGetNext:14' shape=(?,) dtype=float32>},
#  <tf.Tensor 'IteratorGetNext:15' shape=(?,) dtype=int32>)

# %%
#Residual block
def create_residual_block(start, end):
    #Create skip connection
    out = tf.keras.layers.Add()([start, end])  
    return out

#Create custom TF-estimator
def _model_fn(
            features, # This is batch_features from input_fn
            labels,   # This is batch_labels from input_fn
            mode,     # An instance of tf.estimator.ModeKeys
            params):
    
    hidden_layers = []
    skip_start = []
    skip_end = []
    
    #Collect Skip layers info
    for i, l_ in enumerate(params['skip_conns']):
        start, end = l_.split('-')
        start = int(start)
        end = int(end)
        
        skip_start.append(start)
        skip_end.append(end)    
    
    ###########################
    ###### Begin NN model #####
    
    #Create input layer
    inp = tf.feature_column.input_layer(features, params['feature_columns'])
    
    #Create dense hidden layer-1
    lay = tf.layers.dense(inp, 32, activation=tf.nn.relu)
    hidden_layers.append(lay)
    
    #Create more hidden layers-2....
    for i_, l_ in enumerate(params['layers']):
        lay = tf.layers.dense(lay, l_, activation=tf.nn.relu)
        
        #Check if this layer is the end node of a skip-connect
        for ix, s_ in enumerate(skip_end):
            if s_ == i_ + 1:
                #Create skip-conn
                skip_input_idx = skip_start[ix]
                lay = create_residual_block(hidden_layers[skip_input_idx], lay)
                break
        
        #Add Dropout
        lay = tf.layers.dropout(lay, 0.2, (mode == tf.estimator.ModeKeys.TRAIN))
        
        hidden_layers.append(lay)
        
    #Logit + Prediction layer
    logits = tf.layers.dense(lay, params['n_classes'], activation=None)
    predicted_classes = tf.argmax(logits, 1)
    
    ###### End NN model #####
    ###########################
    
    #Return in case of PREDICT mode
    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {
            'class_ids': predicted_classes[:, tf.newaxis],
            'probabilities': tf.nn.softmax(logits),
            'logits': logits
        }
        return tf.estimator.EstimatorSpec(mode, predictions=predictions)
    
    ###############################
    ###### Begin Training Ops #####
    
    #Compute loss
    loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)    
    
    #Training operation
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001)
    train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())
    
    #Add evaluation metrics to Tensorboard in both TRAIN and EVAL
    auc = tf.metrics.auc(labels=labels,
                               predictions=predicted_classes,
                               name='acc_op')
    
    acc = tf.metrics.accuracy(labels=labels,
                               predictions=predicted_classes,
                               name='acc_op')
    
    metrics = {'Accuracy': acc, 'AUC' : auc}
    
    tf.summary.scalar('Accuracy', acc[1])
    tf.summary.scalar('AUC', auc[1])
    
    ###### End Training Ops #####
    #############################    
    
    #Return Estimator object for TRAIN, EVAL
    if mode == tf.estimator.ModeKeys.EVAL:
        return tf.estimator.EstimatorSpec(mode, loss=loss, eval_metric_ops=metrics)
    elif mode == tf.estimator.ModeKeys.TRAIN:
        return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

# %%
# Create estimator train and evaluate function
def train_and_evaluate(output_dir, num_train_steps, train_file, eval_file):    
##### Create Canned estimator instance
    ## setting the checkpoint interval to be much lower for this task
    run_config = tf.estimator.RunConfig(save_checkpoints_secs = 40, 
                                        keep_checkpoint_max = 3)
    
    estimator = tf.estimator.Estimator(
                                        model_fn = _model_fn,
                                        config = run_config,
                                        params={
                                         'feature_columns': create_feature_cols(),
                                          'layers': [64,64,64,64,64,
                                                    64,64,64,64,64,64,
                                                    64,64,64,64,64,64,
                                                    32],
                                          'skip_conns': ['2-6','6-10','10-14'],
                                          'n_classes': 2
                                      })

    train_spec = tf.estimator.TrainSpec(input_fn = read_dataset(
                                                filename = train_file,
                                                mode = tf.estimator.ModeKeys.TRAIN,
                                                batch_size = 128),
                                      max_steps = num_train_steps)
    exp = tf.estimator.LatestExporter("decision", serving_fn)
    eval_spec = tf.estimator.EvalSpec(input_fn = read_dataset(
                                                filename = eval_file,
                                                mode = tf.estimator.ModeKeys.EVAL,
                                                batch_size = 128),
                                    steps = None, 
                                    exporters = exp,
                                    start_delay_secs = 20, # start evaluating after N seconds, 
                                    throttle_secs = 45)  # evaluate every N seconds
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
train_file = os.getcwd() + "\grir_train.csv"
eval_file = os.getcwd() + "\grir_eval.csv"

# %%
#Final trainer
train_and_evaluate(None, num_train_steps=20000, train_file=train_file, eval_file=eval_file)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp
# INFO:tensorflow:Using config: {'_train_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_task_id': 0, '_keep_checkpoint_max': 3, '_num_ps_replicas': 0, '_evaluation_master': '', '_save_summary_steps': 100, '_save_checkpoints_secs': 40, '_tf_random_seed': None, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_is_chief': True, '_global_id_in_cluster': 0, '_task_type': 'worker', '_service': None, '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x00000232C170AB00>, '_device_fn': None, '_num_worker_replicas': 1, '_model_dir': 'C:\\Users\\hrafiq\\AppData\\Local\\Temp\\tmp9_0qx6yp', '_session_config': None}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 40.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:loss = 0.67636144, step = 1
# INFO:tensorflow:global_step/sec: 31.8792
# INFO:tensorflow:loss = 0.5273715, step = 101 (3.139 sec)
# INFO:tensorflow:global_step/sec: 38.9138
# INFO:tensorflow:loss = 0.361255, step = 201 (2.570 sec)
# INFO:tensorflow:global_step/sec: 34.6165
# INFO:tensorflow:loss = 0.17307252, step = 301 (2.892 sec)
# INFO:tensorflow:global_step/sec: 31.7411
# INFO:tensorflow:loss = 0.123401366, step = 401 (3.149 sec)
# INFO:tensorflow:global_step/sec: 30.1754
# INFO:tensorflow:loss = 0.13179621, step = 501 (3.317 sec)
# INFO:tensorflow:global_step/sec: 31.0495
# INFO:tensorflow:loss = 0.25711834, step = 601 (3.220 sec)
# INFO:tensorflow:global_step/sec: 31.5004
# INFO:tensorflow:loss = 0.07294478, step = 701 (3.173 sec)
# INFO:tensorflow:global_step/sec: 26.673
# INFO:tensorflow:loss = 0.024242688, step = 801 (3.751 sec)
# INFO:tensorflow:global_step/sec: 26.9105
# INFO:tensorflow:loss = 0.07479545, step = 901 (3.715 sec)
# INFO:tensorflow:global_step/sec: 29.2808
# INFO:tensorflow:loss = 0.0643978, step = 1001 (3.414 sec)
# INFO:tensorflow:global_step/sec: 28.7822
# INFO:tensorflow:loss = 0.0681591, step = 1101 (3.476 sec)
# INFO:tensorflow:global_step/sec: 31.2334
# INFO:tensorflow:loss = 0.054115616, step = 1201 (3.201 sec)
# INFO:tensorflow:Saving checkpoints for 1209 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-24-07:49:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-1209
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-24-07:49:33
# INFO:tensorflow:Saving dict for global step 1209: AUC = 0.91025835, Accuracy = 0.9230303, global_step = 1209, loss = 0.24373484
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1209: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-1209
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-1209
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\export\decision\temp-b'1548316174'\saved_model.pb
# INFO:tensorflow:global_step/sec: 9.47383
# INFO:tensorflow:loss = 0.020462763, step = 1301 (10.554 sec)
# INFO:tensorflow:global_step/sec: 35.4408
# INFO:tensorflow:loss = 0.096868046, step = 1401 (2.823 sec)
# INFO:tensorflow:global_step/sec: 36.6521
# INFO:tensorflow:loss = 0.18196674, step = 1501 (2.728 sec)
# INFO:tensorflow:global_step/sec: 32.4537
# INFO:tensorflow:loss = 0.11483268, step = 1601 (3.079 sec)
# INFO:tensorflow:global_step/sec: 34.5926
# INFO:tensorflow:loss = 0.13052362, step = 1701 (2.892 sec)
# INFO:tensorflow:global_step/sec: 34.473
# INFO:tensorflow:loss = 0.10626832, step = 1801 (2.901 sec)
# INFO:tensorflow:global_step/sec: 35.1411
# INFO:tensorflow:loss = 0.011871962, step = 1901 (2.847 sec)
# INFO:tensorflow:global_step/sec: 36.0558
# INFO:tensorflow:loss = 0.025394775, step = 2001 (2.773 sec)
# INFO:tensorflow:global_step/sec: 34.4967
# INFO:tensorflow:loss = 0.051161878, step = 2101 (2.897 sec)
# INFO:tensorflow:global_step/sec: 35.5673
# INFO:tensorflow:loss = 0.019560024, step = 2201 (2.812 sec)
# INFO:tensorflow:global_step/sec: 36.1211
# INFO:tensorflow:loss = 0.039250493, step = 2301 (2.769 sec)
# INFO:tensorflow:Saving checkpoints for 2340 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (45 secs).
# INFO:tensorflow:global_step/sec: 29.7969
# INFO:tensorflow:loss = 0.018627182, step = 2401 (3.356 sec)
# INFO:tensorflow:global_step/sec: 35.5418
# INFO:tensorflow:loss = 0.06943898, step = 2501 (2.814 sec)
# INFO:tensorflow:global_step/sec: 35.4344
# INFO:tensorflow:loss = 0.051199812, step = 2601 (2.822 sec)
# INFO:tensorflow:global_step/sec: 34.5379
# INFO:tensorflow:loss = 0.015725918, step = 2701 (2.896 sec)
# INFO:tensorflow:global_step/sec: 34.296
# INFO:tensorflow:loss = 0.05685033, step = 2801 (2.916 sec)
# INFO:tensorflow:global_step/sec: 35.3149
# INFO:tensorflow:loss = 0.021530196, step = 2901 (2.833 sec)
# INFO:tensorflow:global_step/sec: 37.0198
# INFO:tensorflow:loss = 0.117163114, step = 3001 (2.702 sec)
# INFO:tensorflow:global_step/sec: 33.8758
# INFO:tensorflow:loss = 0.08840385, step = 3101 (2.950 sec)
# INFO:tensorflow:global_step/sec: 34.1847
# INFO:tensorflow:loss = 0.036968753, step = 3201 (2.924 sec)
# INFO:tensorflow:global_step/sec: 32.4263
# INFO:tensorflow:loss = 0.034826756, step = 3301 (3.086 sec)
# INFO:tensorflow:global_step/sec: 30.1482
# INFO:tensorflow:loss = 0.014903484, step = 3401 (3.315 sec)
# INFO:tensorflow:global_step/sec: 35.8871
# INFO:tensorflow:loss = 0.17441064, step = 3501 (2.788 sec)
# INFO:tensorflow:global_step/sec: 33.7497
# INFO:tensorflow:loss = 0.013450815, step = 3601 (2.966 sec)
# INFO:tensorflow:global_step/sec: 36.5562
# INFO:tensorflow:loss = 0.0052915146, step = 3701 (2.733 sec)
# INFO:tensorflow:Saving checkpoints for 3705 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-24-07:50:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-3705
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-24-07:50:53
# INFO:tensorflow:Saving dict for global step 3705: AUC = 0.92709357, Accuracy = 0.9230303, global_step = 3705, loss = 0.44154632
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3705: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-3705
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-3705
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\export\decision\temp-b'1548316253'\saved_model.pb
# INFO:tensorflow:global_step/sec: 10.1391
# INFO:tensorflow:loss = 0.016922522, step = 3801 (9.862 sec)
# INFO:tensorflow:global_step/sec: 34.5566
# INFO:tensorflow:loss = 0.047787145, step = 3901 (2.897 sec)
# INFO:tensorflow:global_step/sec: 39.5038
# INFO:tensorflow:loss = 0.014509349, step = 4001 (2.528 sec)
# INFO:tensorflow:global_step/sec: 36.4455
# INFO:tensorflow:loss = 0.021416327, step = 4101 (2.745 sec)
# INFO:tensorflow:global_step/sec: 38.2989
# INFO:tensorflow:loss = 0.010676952, step = 4201 (2.611 sec)
# INFO:tensorflow:global_step/sec: 37.791
# INFO:tensorflow:loss = 0.0030066737, step = 4301 (2.646 sec)
# INFO:tensorflow:global_step/sec: 39.8921
# INFO:tensorflow:loss = 0.036600865, step = 4401 (2.508 sec)
# INFO:tensorflow:global_step/sec: 36.7466
# INFO:tensorflow:loss = 0.03596691, step = 4501 (2.720 sec)
# INFO:tensorflow:global_step/sec: 37.9637
# INFO:tensorflow:loss = 0.0809883, step = 4601 (2.633 sec)
# INFO:tensorflow:global_step/sec: 35.3654
# INFO:tensorflow:loss = 0.024511036, step = 4701 (2.831 sec)
# INFO:tensorflow:global_step/sec: 35.5545
# INFO:tensorflow:loss = 0.035071537, step = 4801 (2.812 sec)
# INFO:tensorflow:global_step/sec: 34.4373
# INFO:tensorflow:loss = 0.04035434, step = 4901 (2.907 sec)
# INFO:tensorflow:Saving checkpoints for 4920 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (45 secs).
# INFO:tensorflow:global_step/sec: 30.0419
# INFO:tensorflow:loss = 0.021233676, step = 5001 (3.324 sec)
# INFO:tensorflow:global_step/sec: 40.3767
# INFO:tensorflow:loss = 0.0040896386, step = 5101 (2.477 sec)
# INFO:tensorflow:global_step/sec: 38.2826
# INFO:tensorflow:loss = 0.014764275, step = 5201 (2.614 sec)
# INFO:tensorflow:global_step/sec: 32.1506
# INFO:tensorflow:loss = 0.010644624, step = 5301 (3.112 sec)
# INFO:tensorflow:global_step/sec: 33.6482
# INFO:tensorflow:loss = 0.009309891, step = 5401 (2.969 sec)
# INFO:tensorflow:global_step/sec: 33.7497
# INFO:tensorflow:loss = 0.007503288, step = 5501 (2.963 sec)
# INFO:tensorflow:global_step/sec: 33.1549
# INFO:tensorflow:loss = 0.03499217, step = 5601 (3.016 sec)
# INFO:tensorflow:global_step/sec: 31.9548
# INFO:tensorflow:loss = 0.00062114367, step = 5701 (3.129 sec)
# INFO:tensorflow:global_step/sec: 35.6051
# INFO:tensorflow:loss = 0.014469576, step = 5801 (2.810 sec)
# INFO:tensorflow:global_step/sec: 38.8699
# INFO:tensorflow:loss = 0.03249702, step = 5901 (2.571 sec)
# INFO:tensorflow:global_step/sec: 34.6135
# INFO:tensorflow:loss = 0.019543005, step = 6001 (2.891 sec)
# INFO:tensorflow:global_step/sec: 33.9915
# INFO:tensorflow:loss = 0.030445553, step = 6101 (2.940 sec)
# INFO:tensorflow:global_step/sec: 36.2653
# INFO:tensorflow:loss = 0.09374101, step = 6201 (2.759 sec)
# INFO:tensorflow:global_step/sec: 37.5636
# INFO:tensorflow:loss = 0.015913105, step = 6301 (2.661 sec)
# INFO:tensorflow:Saving checkpoints for 6309 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-24-07:52:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-6309
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-24-07:52:13
# INFO:tensorflow:Saving dict for global step 6309: AUC = 0.9300938, Accuracy = 0.9327273, global_step = 6309, loss = 0.27703202
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6309: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-6309
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-6309
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\export\decision\temp-b'1548316333'\saved_model.pb
# INFO:tensorflow:global_step/sec: 10.0806
# INFO:tensorflow:loss = 0.12833577, step = 6401 (9.920 sec)
# INFO:tensorflow:global_step/sec: 35.3905
# INFO:tensorflow:loss = 0.016921533, step = 6501 (2.826 sec)
# INFO:tensorflow:global_step/sec: 36.4245
# INFO:tensorflow:loss = 0.004566167, step = 6601 (2.744 sec)
# INFO:tensorflow:global_step/sec: 41.0274
# INFO:tensorflow:loss = 0.0059664585, step = 6701 (2.438 sec)
# INFO:tensorflow:global_step/sec: 35.6061
# INFO:tensorflow:loss = 0.013714262, step = 6801 (2.811 sec)
# INFO:tensorflow:global_step/sec: 33.9654
# INFO:tensorflow:loss = 0.015756577, step = 6901 (2.942 sec)
# INFO:tensorflow:global_step/sec: 35.1406
# INFO:tensorflow:loss = 0.032699566, step = 7001 (2.845 sec)
# INFO:tensorflow:global_step/sec: 35.092
# INFO:tensorflow:loss = 0.041017845, step = 7101 (2.850 sec)
# INFO:tensorflow:global_step/sec: 33.7383
# INFO:tensorflow:loss = 0.007842313, step = 7201 (2.965 sec)
# INFO:tensorflow:global_step/sec: 33.1947
# INFO:tensorflow:loss = 0.03644018, step = 7301 (3.012 sec)
# INFO:tensorflow:global_step/sec: 33.5612
# INFO:tensorflow:loss = 0.05287892, step = 7401 (2.985 sec)
# INFO:tensorflow:Saving checkpoints for 7470 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (45 secs).
# INFO:tensorflow:global_step/sec: 31.7007
# INFO:tensorflow:loss = 0.037356645, step = 7501 (3.148 sec)
# INFO:tensorflow:global_step/sec: 32.6771
# INFO:tensorflow:loss = 0.008191924, step = 7601 (3.062 sec)
# INFO:tensorflow:global_step/sec: 36.3714
# INFO:tensorflow:loss = 0.0034845017, step = 7701 (2.749 sec)
# INFO:tensorflow:global_step/sec: 36.1342
# INFO:tensorflow:loss = 0.0151161505, step = 7801 (2.767 sec)
# INFO:tensorflow:global_step/sec: 32.338
# INFO:tensorflow:loss = 0.005545622, step = 7901 (3.091 sec)
# INFO:tensorflow:global_step/sec: 33.299
# INFO:tensorflow:loss = 0.031112025, step = 8001 (3.005 sec)
# INFO:tensorflow:global_step/sec: 33.9334
# INFO:tensorflow:loss = 0.020787373, step = 8101 (2.947 sec)
# INFO:tensorflow:global_step/sec: 33.3633
# INFO:tensorflow:loss = 0.020515142, step = 8201 (2.996 sec)
# INFO:tensorflow:global_step/sec: 34.9958
# INFO:tensorflow:loss = 0.0011095287, step = 8301 (2.857 sec)
# INFO:tensorflow:global_step/sec: 36.1735
# INFO:tensorflow:loss = 0.0075806016, step = 8401 (2.764 sec)
# INFO:tensorflow:global_step/sec: 36.5715
# INFO:tensorflow:loss = 0.025422394, step = 8501 (2.734 sec)
# INFO:tensorflow:global_step/sec: 36.3581
# INFO:tensorflow:loss = 0.0023769399, step = 8601 (2.752 sec)
# INFO:tensorflow:global_step/sec: 37.2119
# INFO:tensorflow:loss = 0.032014497, step = 8701 (2.685 sec)
# INFO:tensorflow:global_step/sec: 41.8169
# INFO:tensorflow:loss = 0.0058553442, step = 8801 (2.392 sec)
# INFO:tensorflow:Saving checkpoints for 8864 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-24-07:53:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-8864
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-24-07:53:34
# INFO:tensorflow:Saving dict for global step 8864: AUC = 0.93374795, Accuracy = 0.9381818, global_step = 8864, loss = 0.25216988
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8864: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-8864
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-8864
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\export\decision\temp-b'1548316414'\saved_model.pb
# INFO:tensorflow:global_step/sec: 9.61627
# INFO:tensorflow:loss = 0.032180488, step = 8901 (10.399 sec)
# INFO:tensorflow:global_step/sec: 35.7073
# INFO:tensorflow:loss = 0.030747026, step = 9001 (2.802 sec)
# INFO:tensorflow:global_step/sec: 33.1881
# INFO:tensorflow:loss = 0.018339334, step = 9101 (3.013 sec)
# INFO:tensorflow:global_step/sec: 31.6379
# INFO:tensorflow:loss = 0.009039148, step = 9201 (3.163 sec)
# INFO:tensorflow:global_step/sec: 33.2462
# INFO:tensorflow:loss = 0.021126818, step = 9301 (3.006 sec)
# INFO:tensorflow:global_step/sec: 36.679
# INFO:tensorflow:loss = 0.00030433811, step = 9401 (2.726 sec)
# INFO:tensorflow:global_step/sec: 34.9074
# INFO:tensorflow:loss = 0.0032702894, step = 9501 (2.863 sec)
# INFO:tensorflow:global_step/sec: 34.5085
# INFO:tensorflow:loss = 0.0068197222, step = 9601 (2.899 sec)
# INFO:tensorflow:global_step/sec: 35.0796
# INFO:tensorflow:loss = 0.0026985877, step = 9701 (2.852 sec)
# INFO:tensorflow:global_step/sec: 38.9116
# INFO:tensorflow:loss = 0.1598683, step = 9801 (2.568 sec)
# INFO:tensorflow:global_step/sec: 36.679
# INFO:tensorflow:loss = 0.001474289, step = 9901 (2.727 sec)
# INFO:tensorflow:global_step/sec: 35.6562
# INFO:tensorflow:loss = 0.0015622112, step = 10001 (2.805 sec)
# INFO:tensorflow:Saving checkpoints for 10006 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (45 secs).
# INFO:tensorflow:global_step/sec: 30.5547
# INFO:tensorflow:loss = 0.0021806136, step = 10101 (3.273 sec)
# INFO:tensorflow:global_step/sec: 36.7873
# INFO:tensorflow:loss = 0.00077549455, step = 10201 (2.718 sec)
# INFO:tensorflow:global_step/sec: 35.5119
# INFO:tensorflow:loss = 0.008383306, step = 10301 (2.816 sec)
# INFO:tensorflow:global_step/sec: 34.549
# INFO:tensorflow:loss = 0.0050742095, step = 10401 (2.895 sec)
# INFO:tensorflow:global_step/sec: 35.4031
# INFO:tensorflow:loss = 0.014985251, step = 10501 (2.825 sec)
# INFO:tensorflow:global_step/sec: 35.1251
# INFO:tensorflow:loss = 0.0011149237, step = 10601 (2.846 sec)
# INFO:tensorflow:global_step/sec: 32.478
# INFO:tensorflow:loss = 0.025616005, step = 10701 (3.080 sec)
# INFO:tensorflow:global_step/sec: 32.0088
# INFO:tensorflow:loss = 0.00014587503, step = 10801 (3.124 sec)
# INFO:tensorflow:global_step/sec: 32.2618
# INFO:tensorflow:loss = 0.004020733, step = 10901 (3.099 sec)
# INFO:tensorflow:global_step/sec: 30.9373
# INFO:tensorflow:loss = 0.0068059517, step = 11001 (3.234 sec)
# INFO:tensorflow:global_step/sec: 33.1882
# INFO:tensorflow:loss = 0.0043868814, step = 11101 (3.012 sec)
# INFO:tensorflow:global_step/sec: 31.8997
# INFO:tensorflow:loss = 0.018890055, step = 11201 (3.136 sec)
# INFO:tensorflow:global_step/sec: 27.1448
# INFO:tensorflow:loss = 0.03210658, step = 11301 (3.686 sec)
# INFO:tensorflow:Saving checkpoints for 11313 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-24-07:54:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-11313
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-24-07:54:55
# INFO:tensorflow:Saving dict for global step 11313: AUC = 0.9359081, Accuracy = 0.9418182, global_step = 11313, loss = 0.24484834
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11313: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-11313
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-11313
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\export\decision\temp-b'1548316495'\saved_model.pb
# INFO:tensorflow:global_step/sec: 7.70715
# INFO:tensorflow:loss = 0.0017982401, step = 11401 (12.972 sec)
# INFO:tensorflow:global_step/sec: 30.1573
# INFO:tensorflow:loss = 0.00018522487, step = 11501 (3.316 sec)
# INFO:tensorflow:global_step/sec: 32.348
# INFO:tensorflow:loss = 0.0018219939, step = 11601 (3.090 sec)
# INFO:tensorflow:global_step/sec: 30.7151
# INFO:tensorflow:loss = 0.017486952, step = 11701 (3.256 sec)
# INFO:tensorflow:global_step/sec: 32.2961
# INFO:tensorflow:loss = 0.024044262, step = 11801 (3.096 sec)
# INFO:tensorflow:global_step/sec: 33.0342
# INFO:tensorflow:loss = 0.05766969, step = 11901 (3.028 sec)
# INFO:tensorflow:global_step/sec: 31.2536
# INFO:tensorflow:loss = 0.010012103, step = 12001 (3.200 sec)
# INFO:tensorflow:global_step/sec: 33.2435
# INFO:tensorflow:loss = 0.03549537, step = 12101 (3.008 sec)
# INFO:tensorflow:global_step/sec: 33.9334
# INFO:tensorflow:loss = 0.0085183, step = 12201 (2.947 sec)
# INFO:tensorflow:Saving checkpoints for 12286 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (45 secs).
# INFO:tensorflow:global_step/sec: 28.8321
# INFO:tensorflow:loss = 0.0044534053, step = 12301 (3.469 sec)
# INFO:tensorflow:global_step/sec: 31.5403
# INFO:tensorflow:loss = 0.018596265, step = 12401 (3.171 sec)
# INFO:tensorflow:global_step/sec: 27.3779
# INFO:tensorflow:loss = 0.0003493261, step = 12501 (3.652 sec)
# INFO:tensorflow:global_step/sec: 35.2621
# INFO:tensorflow:loss = 0.0042839395, step = 12601 (2.837 sec)
# INFO:tensorflow:global_step/sec: 33.0452
# INFO:tensorflow:loss = 0.004269477, step = 12701 (3.026 sec)
# INFO:tensorflow:global_step/sec: 31.6302
# INFO:tensorflow:loss = 0.012101986, step = 12801 (3.163 sec)
# INFO:tensorflow:global_step/sec: 30.9819
# INFO:tensorflow:loss = 0.0065055843, step = 12901 (3.228 sec)
# INFO:tensorflow:global_step/sec: 29.4359
# INFO:tensorflow:loss = 0.02432643, step = 13001 (3.397 sec)
# INFO:tensorflow:global_step/sec: 33.9803
# INFO:tensorflow:loss = 0.008736835, step = 13101 (2.943 sec)
# INFO:tensorflow:global_step/sec: 31.5802
# INFO:tensorflow:loss = 0.025485333, step = 13201 (3.166 sec)
# INFO:tensorflow:global_step/sec: 32.2439
# INFO:tensorflow:loss = 0.0045437217, step = 13301 (3.102 sec)
# INFO:tensorflow:global_step/sec: 32.3905
# INFO:tensorflow:loss = 0.0109847905, step = 13401 (3.086 sec)
# INFO:tensorflow:global_step/sec: 30.4706
# INFO:tensorflow:loss = 0.051087637, step = 13501 (3.283 sec)
# INFO:tensorflow:Saving checkpoints for 13537 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-24-07:56:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-13537
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-24-07:56:16
# INFO:tensorflow:Saving dict for global step 13537: AUC = 0.92109424, Accuracy = 0.93151516, global_step = 13537, loss = 0.41873634
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13537: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-13537
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-13537
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\export\decision\temp-b'1548316576'\saved_model.pb
# INFO:tensorflow:global_step/sec: 7.3159
# INFO:tensorflow:loss = 0.012217919, step = 13601 (13.668 sec)
# INFO:tensorflow:global_step/sec: 31.3716
# INFO:tensorflow:loss = 0.0008415288, step = 13701 (3.187 sec)
# INFO:tensorflow:global_step/sec: 34.4593
# INFO:tensorflow:loss = 0.00045531985, step = 13801 (2.904 sec)
# INFO:tensorflow:global_step/sec: 33.7971
# INFO:tensorflow:loss = 0.06455686, step = 13901 (2.958 sec)
# INFO:tensorflow:global_step/sec: 34.2128
# INFO:tensorflow:loss = 0.003237128, step = 14001 (2.922 sec)
# INFO:tensorflow:global_step/sec: 33.7041
# INFO:tensorflow:loss = 0.010344039, step = 14101 (2.967 sec)
# INFO:tensorflow:global_step/sec: 32.3172
# INFO:tensorflow:loss = 0.0123975985, step = 14201 (3.094 sec)
# INFO:tensorflow:global_step/sec: 32.817
# INFO:tensorflow:loss = 0.02256706, step = 14301 (3.047 sec)
# INFO:tensorflow:global_step/sec: 33.4875
# INFO:tensorflow:loss = 0.00197179, step = 14401 (2.986 sec)
# INFO:tensorflow:global_step/sec: 35.255
# INFO:tensorflow:loss = 0.023807779, step = 14501 (2.840 sec)
# INFO:tensorflow:Saving checkpoints for 14517 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (45 secs).
# INFO:tensorflow:global_step/sec: 27.9202
# INFO:tensorflow:loss = 0.042723067, step = 14601 (3.580 sec)
# INFO:tensorflow:global_step/sec: 31.3226
# INFO:tensorflow:loss = 0.052842867, step = 14701 (3.192 sec)
# INFO:tensorflow:global_step/sec: 31.4808
# INFO:tensorflow:loss = 0.027476039, step = 14801 (3.178 sec)
# INFO:tensorflow:global_step/sec: 29.6995
# INFO:tensorflow:loss = 0.003163816, step = 14901 (3.366 sec)
# INFO:tensorflow:global_step/sec: 29.6289
# INFO:tensorflow:loss = 0.006107416, step = 15001 (3.375 sec)
# INFO:tensorflow:global_step/sec: 32.958
# INFO:tensorflow:loss = 0.00040907596, step = 15101 (3.034 sec)
# INFO:tensorflow:global_step/sec: 34.3426
# INFO:tensorflow:loss = 0.05926539, step = 15201 (2.912 sec)
# INFO:tensorflow:global_step/sec: 31.8426
# INFO:tensorflow:loss = 0.0432027, step = 15301 (3.139 sec)
# INFO:tensorflow:global_step/sec: 35.2282
# INFO:tensorflow:loss = 0.06383027, step = 15401 (2.839 sec)
# INFO:tensorflow:global_step/sec: 34.6891
# INFO:tensorflow:loss = 0.006685748, step = 15501 (2.884 sec)
# INFO:tensorflow:global_step/sec: 34.2365
# INFO:tensorflow:loss = 0.0023708693, step = 15601 (2.922 sec)
# INFO:tensorflow:global_step/sec: 32.1713
# INFO:tensorflow:loss = 0.008085071, step = 15701 (3.107 sec)
# INFO:tensorflow:Saving checkpoints for 15769 into C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-01-24-07:57:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-15769
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-01-24-07:57:35
# INFO:tensorflow:Saving dict for global step 15769: AUC = 0.94010174, Accuracy = 0.9412121, global_step = 15769, loss = 0.34543693
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15769: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-15769
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Restoring parameters from C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\model.ckpt-15769
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: C:\Users\hrafiq\AppData\Local\Temp\tmp9_0qx6yp\export\decision\temp-b'1548316655'\saved_model.pb
# INFO:tensorflow:global_step/sec: 7.29614
# INFO:tensorflow:loss = 0.043648817, step = 15801 (13.705 sec)
# KeyboardInterrupt

# %%
accuracy_score = classifier.evaluate(input_fn=get_input_fn(training_set, num_epochs=1, shuffle=False))["accuracy"]
print("\nTrain Accuracy: {0:f}\n".format(accuracy_score))

# %%
accuracy_score = classifier.evaluate(input_fn=get_validation_input_fn(test_set, num_epochs=1, shuffle=False))["accuracy"]
print("\nTest Accuracy: {0:f}\n".format(accuracy_score))

# %%
#Run model on Prediction data set
predictions = classifier.predict_classes(input_fn=get_prediction_input_fn(test_set))
for p in list(predictions):
    print(p)

# %%
for i in list(test_set['STATUS']):
    print(i)

# %%
#Predict with disk saved model
from tensorflow.contrib import predictor

export_dir = os.getcwd() + "/tflow_grir_model"
predict_fn = predictor.from_saved_model(export_dir,signature_def_key='predict')

predictions = predict_fn({"DIFGRIRV": [-38100],"NODLIR": [90],"VSTATU": ["1"],"NODLGR": [0],"DIFGRIRD": [-80],"VPATD": [30],
                          "WERKS": ["ML01"],
                          "EKORG": ["1"],"TOTGRQTY": [0],"SCENARIO": ["3"],"TOTIRQTY": [80],"KTOKK": ["1"],"EKGRP": ["A"]})
print(predictions['probabilities'][0,1])
